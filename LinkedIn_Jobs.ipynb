# %% [markdown]
# <a href="https://colab.research.google.com/github/Sheila-Otieno/Data-analysis/blob/main/LinkedIn_Jobs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a6e15379-2019-47ef-ad6c-ae82f2ae2d07" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a6e15379-2019-47ef-ad6c-ae82f2ae2d07">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('LinkedInJobs_MLDataset.csv')

# %%
data.head()
# Out:
#                                   Co_Nm  Co_Pg_Lstd  Emp_Cnt  Flw_Cnt  \
# 0                           HearingLife        True     1171    11417
# 1          Metalcraft of Mayville, Inc.        True      300     2923
# 2  U.S. Tsubaki Power Transmission, LLC        True      314     8487
# 3      Episcopal Communities & Services        True       36      305
# 4                            iHerb, LLC        True     1227    51933
#
#                                              Job_Ttl  \
# 0                              Hearing Care Provider
# 1  Shipping & Receiving Associate 2nd shift (Beav...
# 2                               Manager, Engineering
# 3                                               Cook
# 4        Principal Cloud Security Architect (Remote)
#
#                                             Job_Desc  Is_Supvsr    max_sal  \
# 0  Overview\n\nHearingLife is a national hearing ...      False    5250.00
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 24 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Co_Nm            33242 non-null  object
#  1   Co_Pg_Lstd       33246 non-null  bool
#  2   Emp_Cnt          33246 non-null  int64
#  3   Flw_Cnt          33246 non-null  int64
#  4   Job_Ttl          33246 non-null  object
#  5   Job_Desc         33244 non-null  object
#  6   Is_Supvsr        33246 non-null  bool
#  7   max_sal          33246 non-null  float64
#  8   med_sal          33246 non-null  float64
#  9   min_sal          33246 non-null  float64
#  10  py_prd           33246 non-null  object
#  11  py_lstd          33246 non-null  bool
#  12  wrk_typ          33246 non-null  object
#  13  loc              33246 non-null  object
#  14  st_code          33246 non-null  object
#  15  is_remote        33246 non-null  int64
#  16  views            33246 non-null  int64
# ...

# %%
data = data[['Co_Nm', 'Co_Pg_Lstd', 'Emp_Cnt', 'Job_Ttl', 'max_sal','med_sal', 'min_sal','wrk_typ','loc',
             'st_code','is_remote','views','xp_lvl']]

# %%
data.head()
# Out:
#                                   Co_Nm  Co_Pg_Lstd  Emp_Cnt  \
# 0                           HearingLife        True     1171
# 1          Metalcraft of Mayville, Inc.        True      300
# 2  U.S. Tsubaki Power Transmission, LLC        True      314
# 3      Episcopal Communities & Services        True       36
# 4                            iHerb, LLC        True     1227
#
#                                              Job_Ttl    max_sal    med_sal  \
# 0                              Hearing Care Provider    5250.00    5250.00
# 1  Shipping & Receiving Associate 2nd shift (Beav...       0.00       0.00
# 2                               Manager, Engineering       0.00       0.00
# 3                                               Cook      22.27      22.27
# 4        Principal Cloud Security Architect (Remote)  275834.00  240895.00
#
#      min_sal    wrk_typ               loc st_code  is_remote  views  \
# 0    5250.00  Full-time  Little River, SC      SC          0      9
# ...

# %%
data[['Emp_Cnt', 'is_remote','views']] = data[['Emp_Cnt', 'is_remote','views']].astype(int)
# Out:
# <ipython-input-15-43f1eac1531b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['Emp_Cnt', 'is_remote','views']] = data[['Emp_Cnt', 'is_remote','views']].astype(int)

# %%
data[['max_sal','med_sal', 'min_sal']] = data[['max_sal','med_sal', 'min_sal']].astype(float)
# Out:
# <ipython-input-16-6db38afa3e7e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[['max_sal','med_sal', 'min_sal']] = data[['max_sal','med_sal', 'min_sal']].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33246 entries, 0 to 33245
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Co_Nm       33242 non-null  object
#  1   Co_Pg_Lstd  33246 non-null  bool
#  2   Emp_Cnt     33246 non-null  int64
#  3   Job_Ttl     33246 non-null  object
#  4   max_sal     33246 non-null  float64
#  5   med_sal     33246 non-null  float64
#  6   min_sal     33246 non-null  float64
#  7   wrk_typ     33246 non-null  object
#  8   loc         33246 non-null  object
#  9   st_code     33246 non-null  object
#  10  is_remote   33246 non-null  int64
#  11  views       33246 non-null  int64
#  12  xp_lvl      33246 non-null  object
# dtypes: bool(1), float64(3), int64(3), object(6)
# memory usage: 3.1+ MB

# %%
data['location'] = data['loc'].str.split(',').str[0]
# Out:
# <ipython-input-18-5d6f7138a264>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['location'] = data['loc'].str.split(',').str[0]

# %%
data['location'].head()
# Out:
# 0     Little River
# 1       Beaver Dam
# 2         Bessemer
# 3      Aliso Viejo
# 4    United States
# Name: location, dtype: object

# %%
data.isnull().sum()
# Out:
# Co_Nm         4
# Co_Pg_Lstd    0
# Emp_Cnt       0
# Job_Ttl       0
# max_sal       0
# med_sal       0
# min_sal       0
# wrk_typ       0
# loc           0
# st_code       0
# is_remote     0
# views         0
# xp_lvl        0
# location      0
# dtype: int64

# %%
max_salary = data['max_sal'].max()
print(max_salary)
# Out:
# 1300000.0

# %%
print(data['loc'])
# Out:
# 0                       Little River, SC
# 1                         Beaver Dam, WI
# 2                           Bessemer, AL
# 3                        Aliso Viejo, CA
# 4                          United States
#                       ...
# 33241                         Boston, MA
# 33242                     Greenville, SC
# 33243                    Los Angeles, CA
# 33244    Aurora, Colorado, United States
# 33245                     New London, CT
# Name: loc, Length: 33246, dtype: object

# %%
data.dropna()
# Out:
#                                       Co_Nm  Co_Pg_Lstd  Emp_Cnt  \
# 0                               HearingLife        True     1171
# 1              Metalcraft of Mayville, Inc.        True      300
# 2      U.S. Tsubaki Power Transmission, LLC        True      314
# 3          Episcopal Communities & Services        True       36
# 4                                iHerb, LLC        True     1227
# ...                                     ...         ...      ...
# 33241                                 Crowe        True     9109
# 33242                     Anders Group, LLC        True      170
# 33243                                 Crowe        True     9109
# 33244                     Anders Group, LLC        True      170
# 33245                     Anders Group, LLC        True      170
#
#                                                  Job_Ttl    max_sal  \
# 0                                  Hearing Care Provider    5250.00
# ...

# %%
from google.colab import files
data.to_csv('LinkedInJobs.csv')
files.download('LinkedInJobs.csv')
